# %%
import pandas as pd
import numpy as np

# %% [markdown]
# https://www.kaggle.com/datasets/bourdier/all-tv-series-details-dataset

# %%
tvs = pd.read_csv('C:\\Users\huawei\\Documents\\GitHub\\Capstone-Project\\Tv_show_files\\tvs.csv')
# Out:
# C:\Users\huawei\AppData\Local\Temp\ipykernel_19264\2090021127.py:1: DtypeWarning: Columns (11,12,13,14,15,16,35,36,37,43,44,45,69,70,71,72,73,74,75,76,77,78,79,80,85,86,87,88,89,90,91,92,93,94,95,96,121,122,123,124,125,126,127,128,129,130,131,132,139,140,141,142,143,144,145,146,147,148,149,150,157,158,159,160,161,162,163,164,165,166,167,168,175,176,177,178,179,180,181,182,183,184,185,186) have mixed types. Specify dtype option on import or set low_memory=False.
#   tvs = pd.read_csv('C:\\Users\huawei\\Documents\\GitHub\\Capstone-Project\\File - Tv shows\\tvs.csv')

# %%
tvs
# Out:
#                              _id      id  \
# 0       6457d26c7b901e08b141869d      13
# 1       6457d26c7b901e08b141867a       2
# 2       6457d26c7b901e08b141869f      14
# 3       6457d26c7b901e08b14186a5      15
# 4       6457d26c7b901e08b14186ab      16
# ...                          ...     ...
# 152965  6486d361e48e861edb3d8390  228546
# 152966  6486d361e48e861edb3d8395  228547
# 152967  6486d361e48e861edb3d8397  228548
# 152968  6486d361e48e861edb3d8398  228549
# 152969  6486d361e48e861edb3d8399  228550
#
#                                                      name  \
# 0                              How do you like Wednesday?
# 1                                                  Clerks
# 2                                         Shuriken School
# 3                             Mister Rogers' Neighborhood
# 4                                   Sidewalks: Video Nite
# ...                                                   ...
# ...

# %%
tvs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152970 entries, 0 to 152969
# Columns: 188 entries, _id to __v
# dtypes: bool(1), float64(46), int64(3), object(138)
# memory usage: 218.4+ MB

# %%
tvs = tvs[['id', 'name', 'original_name', 'tagline','in_production', 'status', 'original_language', 'first_air_date',
           'last_air_date', 'number_of_episodes', 'number_of_seasons', 'poster_path', 'vote_average', 'vote_count', 'popularity',
           'origin_country[0]','genres[0].name', 'created_by[0].name', 'production_companies[0].name', 'production_companies[0].origin_country']]

# %%
tvs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152970 entries, 0 to 152969
# Data columns (total 20 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   id                                      152970 non-null  int64
#  1   name                                    152964 non-null  object
#  2   original_name                           152964 non-null  object
#  3   tagline                                 4601 non-null    object
#  4   in_production                           152970 non-null  bool
#  5   status                                  152970 non-null  object
#  6   original_language                       152970 non-null  object
#  7   first_air_date                          121894 non-null  object
#  8   last_air_date                           124031 non-null  object
#  9   number_of_episodes                      152336 non-null  float64
# ...

# %%
tvs['genres[0].name']
# Out:
# 0            Comedy
# 1         Animation
# 2            Comedy
# 3              Kids
# 4               NaN
#             ...
# 152965    Animation
# 152966         Soap
# 152967          NaN
# 152968          NaN
# 152969          NaN
# Name: genres[0].name, Length: 152970, dtype: object

# %% [markdown]
# ------------------------------------------------------------------------------------------------------

# %% [markdown]
# The one above - not good, we do not even have synopsis info
#
# The one bellow is better:    (https://www.kaggle.com/datasets/muralidharbhusal/50000-imdb-tv-and-web-series)

# %%
tvs1 = pd.read_csv('C:\\Users\\huawei\\Documents\\GitHub\\Capstone-Project\\Tv_show_files\\TV Series.csv')

# %%
tvs1
# Out:
#                                     Series Title Release Year Runtime  \
# 0                                      Wednesday     (2022– )  45 min
# 1                                    Yellowstone     (2018– )  60 min
# 2                                The White Lotus  (2021–2023)  60 min
# 3                                           1923  (2022–2023)  60 min
# 4                                      Jack Ryan     (2018– )  60 min
# ...                                          ...          ...     ...
# 49995          Law & Order: Special Victims Unit     (1999– )  60 min
# 49996                                 Doctor Who     (2005– )  45 min
# 49997  The Lord of the Rings: The Rings of Power     (2022– )    ****
# 49998                                   The Bear     (2022– )  30 min
# 49999                               Supernatural  (2005–2020)  44 min
#
#                           Genre Rating  \
# 0        Comedy, Crime, Fantasy    8.2
# 1                Drama, Western    8.7
# ...

# %%
tvs1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Series Title  50000 non-null  object
#  1   Release Year  49800 non-null  object
#  2   Runtime       50000 non-null  object
#  3   Genre         50000 non-null  object
#  4   Rating        50000 non-null  object
#  5   Cast          49909 non-null  object
#  6   Synopsis      50000 non-null  object
# dtypes: object(7)
# memory usage: 2.7+ MB

# %%
tvs1['Series Title'].describe()
# Out:
# count          50000
# unique          9644
# top       The Office
# freq             804
# Name: Series Title, dtype: object

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# https://www.kaggle.com/datasets/harshitshankhdhar/tv-series-dataset
#
# I also like this one, 2000 rows, not many missing values (only in one of the columns)

# %%
tvs2 = pd.read_csv('C:\\Users\\huawei\\Documents\\GitHub\\Capstone-Project\\Tv_show_files\\series_data.csv')

# %%
tvs2
# Out:
#                                             Poster_Link      Series_Title  \
# 0     https://m.media-amazon.com/images/M/MV5BYTRiND...   Game of Thrones
# 1     https://m.media-amazon.com/images/M/MV5BMjhiMz...      Breaking Bad
# 2     https://m.media-amazon.com/images/M/MV5BMTc5Zm...  The Walking Dead
# 3     https://m.media-amazon.com/images/M/MV5BNDVkYj...           Friends
# 4     https://m.media-amazon.com/images/M/MV5BMjEzMD...   Stranger Things
# ...                                                 ...               ...
# 1995  https://m.media-amazon.com/images/M/MV5BYTk4OG...      Shaman Kingu
# 1996  https://m.media-amazon.com/images/M/MV5BMTUyND...    Eerie, Indiana
# 1997  https://m.media-amazon.com/images/M/MV5BMTcxMD...          Gunsmoke
# 1998  https://m.media-amazon.com/images/M/MV5BYWQwNm...         The Cheat
# 1999  https://m.media-amazon.com/images/M/MV5BMjQ5Mj...    Comic Book Men
#
#      Runtime_of_Series Certificate Runtime_of_Episodes  \
# ...

# %%
tvs2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Poster_Link          2000 non-null   object
#  1   Series_Title         2000 non-null   object
#  2   Runtime_of_Series    2000 non-null   object
#  3   Certificate          703 non-null    object
#  4   Runtime_of_Episodes  1957 non-null   object
#  5   Genre                2000 non-null   object
#  6   IMDB_Rating          2000 non-null   float64
#  7   Overview             2000 non-null   object
#  8   Star1                2000 non-null   object
#  9   Star2                2000 non-null   object
#  10  Star3                1999 non-null   object
#  11  Star4                1995 non-null   object
#  12  No_of_Votes          2000 non-null   int64
# dtypes: float64(1), int64(1), object(11)
# memory usage: 203.3+ KB

# %%
tvs2_dropped = tvs2.drop('Certificate', axis = 1)

# %%
tvs2_dropped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Poster_Link          2000 non-null   object
#  1   Series_Title         2000 non-null   object
#  2   Runtime_of_Series    2000 non-null   object
#  3   Runtime_of_Episodes  1957 non-null   object
#  4   Genre                2000 non-null   object
#  5   IMDB_Rating          2000 non-null   float64
#  6   Overview             2000 non-null   object
#  7   Star1                2000 non-null   object
#  8   Star2                2000 non-null   object
#  9   Star3                1999 non-null   object
#  10  Star4                1995 non-null   object
#  11  No_of_Votes          2000 non-null   int64
# dtypes: float64(1), int64(1), object(10)
# memory usage: 187.6+ KB

# %% [markdown]
# ------------------------------------------------------------------------------------------

# %% [markdown]
# https://www.kaggle.com/datasets/suraj520/imdb-tv-series-data/data
#
# Very good as well

# %%
import os

parent_folder_path = '/kaggle/input/imdb-tv-series-data'

parent_folder_path = 'C:\\Users\\huawei\\Documents\\GitHub\\Capstone-Project\\Tv_show_files\\archive'

# Initialize an empty list to store the dataframes
dfs = []

# Iterate over each file in the parent folder
for root, dirs, files in os.walk(parent_folder_path):
    for filename in files:
        if filename.endswith('.csv'):
            file_path = os.path.join(root, filename)

            # Read the CSV file into a dataframe
            df = pd.read_csv(file_path)

            # Add a new column with a unique value for each file
            df['UniqueValue'] = filename.split('.')[0]  # You can modify this line to assign a different unique value

            # Append the dataframe to the list
            dfs.append(df)

# Concatenate all dataframes into a single dataframe
shows = pd.concat(dfs, ignore_index=True)
# Out:
# C:\Users\huawei\AppData\Local\Temp\ipykernel_19264\3370329746.py:26: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   shows = pd.concat(dfs, ignore_index=True)

# %%
shows
# Out:
#                                       Title     IMDb ID Release Year  \
# 0       Spider-Man: Across the Spider-Verse   tt9362722         2023
# 1                                     FUBAR  tt13064902       2023–
# 2                                     Barry   tt5348176    2018–2023
# 3                      John Wick: Chapter 4  tt10366206         2023
# 4                                    Fast X   tt5433140         2023
# ...                                     ...         ...          ...
# 236823            How to Blow Up a Pipeline  tt21440780         2022
# 236824                       Hell on Wheels   tt1699748    2011–2016
# 236825                The Magnificent Seven   tt0054047         1960
# 236826                          Wagon Train   tt0050073    1957–1965
# 236827                            Desperado   tt0112851         1995
#
#                                Genre  \
# 0       Animation, Action, Adventure
# 1        Action, Adventure, Thriller
# ...

# %%
shows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236828 entries, 0 to 236827
# Data columns (total 12 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Title            236828 non-null  object
#  1   IMDb ID          236828 non-null  object
#  2   Release Year     236819 non-null  object
#  3   Genre            236828 non-null  object
#  4   Cast             235956 non-null  object
#  5   Synopsis         236828 non-null  object
#  6   Rating           236828 non-null  float64
#  7   Runtime          216983 non-null  object
#  8   Certificate      169091 non-null  object
#  9   Number of Votes  236828 non-null  object
#  10  Gross Revenue    45611 non-null   object
#  11  UniqueValue      236828 non-null  object
# dtypes: float64(1), object(11)
# memory usage: 21.7+ MB

# %%
shows.describe()
# Out:
#              Rating
# count  99186.000000
# mean       6.498823
# std        1.339605
# min        1.000000
# 25%        5.700000
# 50%        6.600000
# 75%        7.400000
# max       10.000000

# %%
tvs1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Series Title  50000 non-null  object
#  1   Release Year  49800 non-null  object
#  2   Runtime       50000 non-null  object
#  3   Genre         50000 non-null  object
#  4   Rating        50000 non-null  object
#  5   Cast          49909 non-null  object
#  6   Synopsis      50000 non-null  object
# dtypes: object(7)
# memory usage: 2.7+ MB

# %%
tvs2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Poster_Link          2000 non-null   object
#  1   Series_Title         2000 non-null   object
#  2   Runtime_of_Series    2000 non-null   object
#  3   Certificate          703 non-null    object
#  4   Runtime_of_Episodes  1957 non-null   object
#  5   Genre                2000 non-null   object
#  6   IMDB_Rating          2000 non-null   float64
#  7   Overview             2000 non-null   object
#  8   Star1                2000 non-null   object
#  9   Star2                2000 non-null   object
#  10  Star3                1999 non-null   object
#  11  Star4                1995 non-null   object
#  12  No_of_Votes          2000 non-null   int64
# dtypes: float64(1), int64(1), object(11)
# memory usage: 203.3+ KB

# %%
shows['Title'].nunique()
# Out:
# 99186

# %%
duplicates_count = shows.duplicated().sum()
print("Number of duplicates in the DataFrame:", duplicates_count)
# Out:
# Number of duplicates in the DataFrame: 44725

# %%
print("Shape of DataFrame before dropping duplicates:", shows.shape)

# Dropping duplicates
shows.drop_duplicates(subset='Title', keep='first', inplace=True)

# Verify the changes by printing the updated DataFrame shape
print("Shape of DataFrame after dropping duplicates:", shows.shape)
# Out:
# Shape of DataFrame before dropping duplicates: (236828, 12)
# Shape of DataFrame after dropping duplicates: (99186, 12)

# %%
shows.duplicated().sum()
# Out:
# 0

# %%
shows['Title'].nunique()
# Out:
# 99186

# %%
tvs1['Series Title'].nunique()
# Out:
# 9644

# %%
print("Shape of DataFrame before dropping duplicates:", tvs1.shape)

# Dropping duplicates from the DataFrame
tvs1.drop_duplicates(subset='Series Title', keep='first', inplace=True)

# Verify the changes by printing the updated DataFrame shape
print("Shape of DataFrame after dropping duplicates:", tvs1.shape)
# Out:
# Shape of DataFrame before dropping duplicates: (9644, 7)
# Shape of DataFrame after dropping duplicates: (9644, 7)

# %%
tvs2['Series_Title'].nunique()
# Out:
# 1956

# %%
print("Shape of DataFrame before dropping duplicates:", tvs2.shape)

# Dropping duplicates from the DataFrame
tvs2.drop_duplicates(subset='Series_Title', keep='first', inplace=True)

# Verify the changes by printing the updated DataFrame shape
print("Shape of DataFrame after dropping duplicates:", tvs2.shape)
# Out:
# Shape of DataFrame before dropping duplicates: (2000, 13)
# Shape of DataFrame after dropping duplicates: (1956, 13)

# %%
tvs1.rename(columns={'Series Title': 'Title', 'B': 'Column2'}, inplace=True)
tvs2.rename(columns={'Series_Title': 'Title','Runtime_of_Series':'Release Year', 'Runtime_of_Episodes':'Runtime', 
                     'IMDB_Rating': 'Rating', 'No_of_Votes':'Number of Votes', 'Overview': 'Synopsis'}, inplace = True)

# %%
shows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99186 entries, 0 to 234577
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            99186 non-null  object
#  1   IMDb ID          99186 non-null  object
#  2   Release Year     99180 non-null  object
#  3   Genre            99186 non-null  object
#  4   Cast             98593 non-null  object
#  5   Synopsis         99186 non-null  object
#  6   Rating           99186 non-null  float64
#  7   Runtime          88829 non-null  object
#  8   Certificate      54372 non-null  object
#  9   Number of Votes  99186 non-null  object
#  10  Gross Revenue    11938 non-null  object
#  11  UniqueValue      99186 non-null  object
# dtypes: float64(1), object(11)
# memory usage: 9.8+ MB

# %%
tvs1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9644 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         9644 non-null   object
#  1   Release Year  9454 non-null   object
#  2   Runtime       9644 non-null   object
#  3   Genre         9644 non-null   object
#  4   Rating        9644 non-null   object
#  5   Cast          9561 non-null   object
#  6   Synopsis      9644 non-null   object
# dtypes: object(7)
# memory usage: 602.8+ KB

# %%
titles_df1 = set(shows['Title'])
titles_df2 = set(tvs1['Title'])
titles_df3 = set(tvs2['Title'])

# Find the unique titles across all three DataFrames
unique_titles_across_all = titles_df1.intersection(titles_df2, titles_df3)

# Find the count of unique titles in each DataFrame individually
count_unique_titles_df1 = len(titles_df1 - titles_df2 - titles_df3)
count_unique_titles_df2 = len(titles_df2 - titles_df1 - titles_df3)
count_unique_titles_df3 = len(titles_df3 - titles_df1 - titles_df2)

# Find the count of unique titles across all DataFrames
count_unique_titles_across_all = len(unique_titles_across_all)

# Output counts of unique titles
print("Count of unique titles in shows:", count_unique_titles_df1)
print("Count of unique titles in tvs1:", count_unique_titles_df2)
print("Count of unique titles in tvs2:", count_unique_titles_df3)
print("Intersection between the datasets:", count_unique_titles_across_all)
# Out:
# Count of unique titles in shows: 92351
# Count of unique titles in tvs1: 2664
# Count of unique titles in tvs2: 33
# Intersection between the datasets: 1700

# %%
# Assuming df3 is your third DataFrame
tvs2['Cast'] = tvs2[['Star1', 'Star2', 'Star3', 'Star4']].fillna('').agg(', '.join, axis=1)
# Drop individual star columns
tvs2.drop(['Star1', 'Star2', 'Star3', 'Star4'], axis=1, inplace=True)

# %% [markdown]
# ## Merging the Datasets

# %%
final_shows = pd.concat([shows, tvs1, tvs2])

# %%
print("Shape of DataFrame before dropping duplicates:", final_shows.shape)

# Dropping duplicates from the DataFrame
final_shows.drop_duplicates(subset='Title', keep='first', inplace=True)

#Dropping unnecessary columns
final_shows.drop(['UniqueValue', 'Poster_Link'], axis=1, inplace=True)

# Verify the changes by printing the updated DataFrame shape
print("Shape of DataFrame after dropping duplicates:", final_shows.shape)
# Out:
# Shape of DataFrame before dropping duplicates: (110786, 13)
# Shape of DataFrame after dropping duplicates: (102067, 11)

# %%
final_shows['Title'].nunique()
# Out:
# 102067

# %%
final_shows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 102067 entries, 0 to 1952
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Title            102067 non-null  object
#  1   IMDb ID          99186 non-null   object
#  2   Release Year     101923 non-null  object
#  3   Genre            102067 non-null  object
#  4   Cast             101428 non-null  object
#  5   Synopsis         102067 non-null  object
#  6   Rating           102067 non-null  object
#  7   Runtime          91707 non-null   object
#  8   Certificate      54387 non-null   object
#  9   Number of Votes  99219 non-null   object
#  10  Gross Revenue    11938 non-null   object
# dtypes: object(11)
# memory usage: 9.3+ MB

# %%
final_shows
# Out:
#                                     Title     IMDb ID Release Year  \
# 0     Spider-Man: Across the Spider-Verse   tt9362722         2023
# 1                                   FUBAR  tt13064902       2023–
# 2                                   Barry   tt5348176    2018–2023
# 3                    John Wick: Chapter 4  tt10366206         2023
# 4                                  Fast X   tt5433140         2023
# ...                                   ...         ...          ...
# 1712                           Bang Baang         NaN          NaN
# 1823                                 High         NaN          NaN
# 1919                             SideHero         NaN          NaN
# 1940                       Mutlu Ol Yeter         NaN          NaN
# 1952                     Shabhaye Barareh         NaN          NaN
#
#                              Genre  \
# 0     Animation, Action, Adventure
# 1      Action, Adventure, Thriller
# 2            Action, Comedy, Crime
# ...

# %%
final_shows['Title'].value_counts()
# Out:
# Title
# Spider-Man: Across the Spider-Verse    1
# Rölli and the Golden Key               1
# Gallo corriente, gallo valiente        1
# Ghunghat                               1
# Betty Boop- Judge for a Day            1
#                                       ..
# Dancing Queens                         1
# Blue Murder at St. Trinian's           1
# Pop Kaun                               1
# The Mule                               1
# Shabhaye Barareh                       1
# Name: count, Length: 102067, dtype: int64

# %%
game_titles = final_shows[final_shows['Title'].str.contains('untitled', case=False)]

# Display rows where the 'Title' column contains the word 'game'
print(game_titles)
# Out:
#                                                     Title     IMDb ID  \
# 20823                                Untitled Pizza Movie  tt11469922
# 35565           Untitled Bill Russell/Netflix Documentary  tt18271440
# 71815                  Untitled Chris Cornell Documentary   tt9860834
# 73334                 Untitled Dave Chappelle Documentary  tt14727094
# 130429                              Untitled Horror Movie  tt12624584
# 151029                                         (Untitled)   tt1132193
# 233598                   Untitled Macbeth Western Project   tt4840492
# 1511                    Untitled Rick & Michonne Spin-Off         NaN
# 3999            Untitled Jon Snow/Game of Thrones Spinoff         NaN
# 4219       Untitled Apple/Godzilla and the Titans Project         NaN
# 4925                          Untitled the Batman Spinoff         NaN
# 5890            Untitled the Walking Dead Spinoff Project         NaN
# ...

# %%
print(len(game_titles))
# Out:
# 20

# %%
# Assuming 'merged_df' is your DataFrame
final_shows = final_shows[~final_shows['Title'].str.contains('untitled', case=False)]

# Display updated DataFrame after removing rows with 'untitled' in the 'Title' column
final_shows
# Out:
#                                     Title     IMDb ID Release Year  \
# 0     Spider-Man: Across the Spider-Verse   tt9362722         2023
# 1                                   FUBAR  tt13064902       2023–
# 2                                   Barry   tt5348176    2018–2023
# 3                    John Wick: Chapter 4  tt10366206         2023
# 4                                  Fast X   tt5433140         2023
# ...                                   ...         ...          ...
# 1712                           Bang Baang         NaN     (2021– )
# 1823                                 High         NaN     (2020– )
# 1919                             SideHero         NaN     (2018– )
# 1940                       Mutlu Ol Yeter         NaN       (2015)
# 1952                     Shabhaye Barareh         NaN  (2005–2006)
#
#                              Genre  \
# 0     Animation, Action, Adventure
# 1      Action, Adventure, Thriller
# 2            Action, Comedy, Crime
# ...

# %%
missing_release_year = final_shows[final_shows['Release Year'].isnull()]

# Display rows with missing values in the 'Release Year' column
print(len(missing_release_year))
# Out:
# 132

# %%
final_shows.dropna(subset=['Release Year'], inplace=True)

# Display information or updated DataFrame after removing rows with missing 'Release Year'
final_shows.info()  # Show DataFrame information after removal
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 101915 entries, 0 to 1952
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Title            101915 non-null  object
#  1   IMDb ID          99173 non-null   object
#  2   Release Year     101915 non-null  object
#  3   Genre            101915 non-null  object
#  4   Cast             101302 non-null  object
#  5   Synopsis         101915 non-null  object
#  6   Rating           101915 non-null  object
#  7   Runtime          91560 non-null   object
#  8   Certificate      54383 non-null   object
#  9   Number of Votes  99206 non-null   object
#  10  Gross Revenue    11937 non-null   object
# dtypes: object(11)
# memory usage: 9.3+ MB
